# %%
import pandas as pd
import numpy as np
import  matplotlib.pyplot as plt
from mlxtend.frequent_patterns import apriori  #apriori算法
from mlxtend.frequent_patterns import association_rules  #计算关联规则的函数

# %%
data_wine1 = pd.read_csv("./datamining_dataset/winemag-data_first150k.csv")
data_wine2 = pd.read_csv("./datamining_dataset/winemag-data-130k-v2.csv")

data_wine = pd.concat([data_wine1,data_wine2],axis = 0,ignore_index=True)

# %%
data_wine.head()
# Out:
#    Unnamed: 0 country                                        description  \
# 0           0      US  This tremendous 100% varietal wine hails from ...
# 1           1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2           2      US  Mac Watson honors the memory of a wine once ma...
# 3           3      US  This spent 20 months in 30% new French oak, an...
# 4           4  France  This is the top wine from La Bégude, named aft...
#
#                             designation  points  price        province  \
# 0                     Martha's Vineyard      96  235.0      California
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
# 3                               Reserve      96   65.0          Oregon
# 4                            La Brûlade      95   66.0        Provence
#
#             region_1           region_2 taster_name taster_twitter_handle  \
# 0        Napa Valley               Napa         NaN                   NaN
# 1               Toro                NaN         NaN                   NaN
# 2     Knights Valley             Sonoma         NaN                   NaN
# 3  Willamette Valley  Willamette Valley         NaN                   NaN
# 4             Bandol                NaN         NaN                   NaN
#
#   title             variety                   winery
# 0   NaN  Cabernet Sauvignon                    Heitz
# 1   NaN       Tinta de Toro  Bodega Carmen Rodríguez
# 2   NaN     Sauvignon Blanc                 Macauley
# 3   NaN          Pinot Noir                    Ponzi
# 4   NaN  Provence red blend     Domaine de la Bégude

# %%
df = data_wine[ (data_wine.designation=='Reserve') & (data_wine.country=='Australia') ][['price','variety','winery']]
#利用get_dummies()方法转换成适合进行关联规则挖掘的形式
df = pd.get_dummies(df) 
df = df.drop('price' ,1)

# %%
df.head()
# Out:
#        variety_Cabernet Sauvignon  variety_Cabernet Sauvignon-Shiraz  \
# 8492                            0                                  0
# 9917                            0                                  0
# 11386                           0                                  0
# 14005                           0                                  0
# 14878                           0                                  0
#
#        variety_Chardonnay  variety_Durif  variety_Merlot  \
# 8492                    1              0               0
# 9917                    0              0               0
# 11386                   0              0               0
# 14005                   0              0               0
# 14878                   1              0               0
#
#        variety_Pinot Grigio  variety_Pinot Noir  variety_Riesling  \
# 8492                      0                   0                 0
# 9917                      0                   1                 0
# 11386                     0                   0                 0
# 14005                     0                   1                 0
# 14878                     0                   0                 0
#
#        variety_Sauvignon Blanc  variety_Shiraz          ...            \
# 8492                         0               0          ...
# 9917                         0               0          ...
# 11386                        0               1          ...
# 14005                        0               0          ...
# 14878                        0               0          ...
#
#        winery_Stonier  winery_Syan  winery_Tahbilk  winery_Tall Poppy  \
# 8492                0            0               0                  0
# 9917                0            0               0                  0
# 11386               0            0               0                  0
# 14005               0            0               0                  0
# 14878               1            0               0                  0
#
#        winery_Temple Bruer  winery_Tyrrell's  winery_Warrabilla  winery_Wise  \
# 8492                     0                 0                  0            0
# 9917                     0                 0                  0            0
# 11386                    0                 0                  0            0
# 14005                    0                 0                  0            0
# 14878                    0                 0                  0            0
#
#        winery_Yellow Tail  winery_Yering Station
# 8492                    0                      0
# 9917                    0                      0
# 11386                   0                      0
# 14005                   0                      1
# 14878                   0                      0
#
# [5 rows x 57 columns]

# %%
frequent_itemsets = apriori(df,use_colnames=True, min_support=0.025)
frequent_itemsets
# Out:
#      support                                           itemsets
# 0   0.151685                       [variety_Cabernet Sauvignon]
# 1   0.275281                               [variety_Chardonnay]
# 2   0.095506                               [variety_Pinot Noir]
# 3   0.067416                                 [variety_Riesling]
# 4   0.286517                                   [variety_Shiraz]
# 5   0.033708                          [variety_Shiraz-Viognier]
# 6   0.033708                               [winery_Green Point]
# 7   0.028090                   [winery_Henry's Drive Vignerons]
# 8   0.202247                             [winery_Jacob's Creek]
# 9   0.028090                            [winery_Passing Clouds]
# 10  0.044944                             [winery_Penley Estate]
# 11  0.028090                                [winery_Stonehaven]
# 12  0.033708                                   [winery_Stonier]
# 13  0.039326                                   [winery_Tahbilk]
# 14  0.039326                               [winery_Yellow Tail]
# 15  0.123596                            [winery_Yering Station]
# 16  0.044944  [variety_Cabernet Sauvignon, winery_Penley Est...
# 17  0.028090       [variety_Cabernet Sauvignon, winery_Tahbilk]
# 18  0.056180         [variety_Chardonnay, winery_Jacob's Creek]
# 19  0.028090        [variety_Chardonnay, winery_Yering Station]
# 20  0.056180        [variety_Pinot Noir, winery_Yering Station]
# 21  0.044944           [variety_Riesling, winery_Jacob's Creek]
# 22  0.028090   [variety_Shiraz, winery_Henry's Drive Vignerons]
# 23  0.056180             [variety_Shiraz, winery_Jacob's Creek]
# 24  0.028090            [variety_Shiraz, winery_Passing Clouds]
# 25  0.033708   [variety_Shiraz-Viognier, winery_Yering Station]

# %%
#导出关联规则，计算支持度和置信度，并使用lift、leverage、conviction指标对规则进行评价，设置lift 最小值为1.25
rules =  association_rules(frequent_itemsets, metric='lift', min_threshold=1.25)
rules
# Out:
#                          antecedants                       consequents  \
# 0             (winery_Penley Estate)      (variety_Cabernet Sauvignon)
# 1       (variety_Cabernet Sauvignon)            (winery_Penley Estate)
# 2                   (winery_Tahbilk)      (variety_Cabernet Sauvignon)
# 3       (variety_Cabernet Sauvignon)                  (winery_Tahbilk)
# 4            (winery_Yering Station)              (variety_Pinot Noir)
# 5               (variety_Pinot Noir)           (winery_Yering Station)
# 6             (winery_Jacob's Creek)                (variety_Riesling)
# 7                 (variety_Riesling)            (winery_Jacob's Creek)
# 8                   (variety_Shiraz)  (winery_Henry's Drive Vignerons)
# 9   (winery_Henry's Drive Vignerons)                  (variety_Shiraz)
# 10                  (variety_Shiraz)           (winery_Passing Clouds)
# 11           (winery_Passing Clouds)                  (variety_Shiraz)
# 12           (winery_Yering Station)         (variety_Shiraz-Viognier)
# 13         (variety_Shiraz-Viognier)           (winery_Yering Station)
#
#     antecedent support  consequent support   support  confidence      lift  \
# 0             0.044944            0.151685  0.044944    1.000000  6.592593
# 1             0.151685            0.044944  0.044944    0.296296  6.592593
# 2             0.039326            0.151685  0.028090    0.714286  4.708995
# 3             0.151685            0.039326  0.028090    0.185185  4.708995
# 4             0.123596            0.095506  0.056180    0.454545  4.759358
# 5             0.095506            0.123596  0.056180    0.588235  4.759358
# 6             0.202247            0.067416  0.044944    0.222222  3.296296
# 7             0.067416            0.202247  0.044944    0.666667  3.296296
# 8             0.286517            0.028090  0.028090    0.098039  3.490196
# 9             0.028090            0.286517  0.028090    1.000000  3.490196
# 10            0.286517            0.028090  0.028090    0.098039  3.490196
# 11            0.028090            0.286517  0.028090    1.000000  3.490196
# 12            0.123596            0.033708  0.033708    0.272727  8.090909
# 13            0.033708            0.123596  0.033708    1.000000  8.090909
#
#     leverage  conviction
# 0   0.038126         inf
# 1   0.038126    1.357185
# 2   0.022125    2.969101
# 3   0.022125    1.179009
# 4   0.044376    1.658240
# 5   0.044376    2.128411
# 6   0.031309    1.199037
# 7   0.031309    2.393258
# 8   0.020042    1.077553
# 9   0.020042         inf
# 10  0.020042    1.077553
# 11  0.020042         inf
# 12  0.029542    1.328652
# 13  0.029542         inf

# %%
#对挖掘结果进行分析：将lift值大于6的降序输出
rules[(rules.lift>6)].sort_values(by=['lift'], ascending=False)
# Out:
#                      antecedants                   consequents  \
# 13     (variety_Shiraz-Viognier)       (winery_Yering Station)
# 12       (winery_Yering Station)     (variety_Shiraz-Viognier)
# 0         (winery_Penley Estate)  (variety_Cabernet Sauvignon)
# 1   (variety_Cabernet Sauvignon)        (winery_Penley Estate)
#
#     antecedent support  consequent support   support  confidence      lift  \
# 13            0.033708            0.123596  0.033708    1.000000  8.090909
# 12            0.123596            0.033708  0.033708    0.272727  8.090909
# 0             0.044944            0.151685  0.044944    1.000000  6.592593
# 1             0.151685            0.044944  0.044944    0.296296  6.592593
#
#     leverage  conviction
# 13  0.029542         inf
# 12  0.029542    1.328652
# 0   0.038126         inf
# 1   0.038126    1.357185

# %%
#可视化展示：绘制关联规则支持度和置信度的散点图
plt.xlabel('support')
plt.ylabel('confidence')
plt.scatter(rules.support,rules.confidence)
plt.show()

# %%
df1=data_wine[ (data_wine.variety=='Shiraz-Viognier')  ][['price','country','winery']]
df1.head(5)
# Out:
#        price    country                        winery
# 7636   125.0  Australia                      Torbreck
# 10512  225.0  Australia                      Torbreck
# 15814   23.0  Australia                Off the Leash.
# 19943   20.0  Australia                   Wirra Wirra
# 20180   18.0  Australia  Domaine Terlato & Chapoutier

# %%
for index,i in enumerate(df1.price.values):
    if i>=10.0 and i <30.0:
        df1.iat[index,0]=5
    elif i>=30.0 and i <50.0:
        df1.iat[index,0]=4
    elif i>=50.0 and i <100.0:
        df1.iat[index,0]=3
    elif i>=100.0 and i <200.0:
        df1.iat[index,0]=2
    else:
        df1.iat[index,0]=1

# %%
class_mapping = {5: 'D', 4: 'C',3: 'B',2: 'A',1: 'S'}
price_level=df1.price.map(class_mapping)
df1=pd.concat([df1,price_level],axis = 1)

# %%
df1.columns = ['price_float', 'country', 'winery', 'price_level']
df1.head(10)
# Out:
#        price_float    country                        winery price_level
# 7636           2.0  Australia                      Torbreck           A
# 10512          1.0  Australia                      Torbreck           S
# 15814          5.0  Australia                Off the Leash.           D
# 19943          5.0  Australia                   Wirra Wirra           D
# 20180          5.0  Australia  Domaine Terlato & Chapoutier           D
# 20306          5.0  Australia                       Gemtree           D
# 20580          4.0  Australia                    De Bortoli           C
# 20775          5.0  Australia                    De Bortoli           D
# 21271          5.0  Australia            Innocent Bystander           D
# 21772          5.0  Australia                       Yalumba           D

# %%
df1=df1.drop('price_float',1)

# %%
#将price一列离散化后的数据如下
df1.head(10)
# Out:
#          country                        winery price_level
# 7636   Australia                      Torbreck           A
# 10512  Australia                      Torbreck           S
# 15814  Australia                Off the Leash.           D
# 19943  Australia                   Wirra Wirra           D
# 20180  Australia  Domaine Terlato & Chapoutier           D
# 20306  Australia                       Gemtree           D
# 20580  Australia                    De Bortoli           C
# 20775  Australia                    De Bortoli           D
# 21271  Australia            Innocent Bystander           D
# 21772  Australia                       Yalumba           D

# %%
#利用get_dummies()方法转换成适合进行关联规则挖掘的形式
df1=pd.get_dummies(df1)
df1.head(10)
# Out:
#        country_Australia  country_New Zealand  country_South Africa  \
# 7636                   1                    0                     0
# 10512                  1                    0                     0
# 15814                  1                    0                     0
# 19943                  1                    0                     0
# 20180                  1                    0                     0
# 20306                  1                    0                     0
# 20580                  1                    0                     0
# 20775                  1                    0                     0
# 21271                  1                    0                     0
# 21772                  1                    0                     0
#
#        country_US  winery_5OS Project  winery_Alkoomi  winery_Angove's  \
# 7636            0                   0               0                0
# 10512           0                   0               0                0
# 15814           0                   0               0                0
# 19943           0                   0               0                0
# 20180           0                   0               0                0
# 20306           0                   0               0                0
# 20580           0                   0               0                0
# 20775           0                   0               0                0
# 21271           0                   0               0                0
# 21772           0                   0               0                0
#
#        winery_Battle of Bosworth  winery_Bilancia  winery_Creed of Barossa  \
# 7636                           0                0                        0
# 10512                          0                0                        0
# 15814                          0                0                        0
# 19943                          0                0                        0
# 20180                          0                0                        0
# 20306                          0                0                        0
# 20580                          0                0                        0
# 20775                          0                0                        0
# 21271                          0                0                        0
# 21772                          0                0                        0
#
#            ...        winery_Wirra Wirra  winery_Woop Woop  winery_Yalumba  \
# 7636       ...                         0                 0               0
# 10512      ...                         0                 0               0
# 15814      ...                         0                 0               0
# 19943      ...                         1                 0               0
# 20180      ...                         0                 0               0
# 20306      ...                         0                 0               0
# 20580      ...                         0                 0               0
# 20775      ...                         0                 0               0
# 21271      ...                         0                 0               0
# 21772      ...                         0                 0               1
#
#        winery_Yarra Yering  winery_Yering Station  price_level_A  \
# 7636                     0                      0              1
# 10512                    0                      0              0
# 15814                    0                      0              0
# 19943                    0                      0              0
# 20180                    0                      0              0
# 20306                    0                      0              0
# 20580                    0                      0              0
# 20775                    0                      0              0
# 21271                    0                      0              0
# 21772                    0                      0              0
#
#        price_level_B  price_level_C  price_level_D  price_level_S
# 7636               0              0              0              0
# 10512              0              0              0              1
# 15814              0              0              1              0
# 19943              0              0              1              0
# 20180              0              0              1              0
# 20306              0              0              1              0
# 20580              0              1              0              0
# 20775              0              0              1              0
# 21271              0              0              1              0
# 21772              0              0              1              0
#
# [10 rows x 44 columns]

# %%
pd.options.display.max_colwidth=100
#导出频繁项集，设置最小支持度为0.05
frequent_itemsets1 = apriori(df1,use_colnames=True, min_support=0.05)
frequent_itemsets1
# Out:
#      support  \
# 0   0.930233
# 1   0.062016
# 2   0.069767
# 3   0.062016
# 4   0.054264
# 5   0.054264
# 6   0.100775
# 7   0.085271
# 8   0.069767
# 9   0.054264
# 10  0.054264
# 11  0.240310
# 12  0.604651
# 13  0.062016
# 14  0.069767
# 15  0.062016
# 16  0.054264
# 17  0.054264
# 18  0.100775
# 19  0.085271
# 20  0.069767
# 21  0.054264
# 22  0.054264
# 23  0.201550
# 24  0.573643
# 25  0.069767
# 26  0.054264
# 27  0.054264
# 28  0.054264
# 29  0.069767
# 30  0.054264
# 31  0.054264
# 32  0.054264
#
#                                                                    itemsets
# 0                                                       [country_Australia]
# 1                                                       [winery_De Bortoli]
# 2                                     [winery_Domaine Terlato & Chapoutier]
# 3                                                    [winery_Hugh Hamilton]
# 4                                               [winery_Innocent Bystander]
# 5                                                  [winery_Kangarilla Road]
# 6                                                         [winery_Torbreck]
# 7                                                          [winery_Yalumba]
# 8                                                   [winery_Yering Station]
# 9                                                           [price_level_A]
# 10                                                          [price_level_B]
# 11                                                          [price_level_C]
# 12                                                          [price_level_D]
# 13                                   [country_Australia, winery_De Bortoli]
# 14                 [country_Australia, winery_Domaine Terlato & Chapoutier]
# 15                                [country_Australia, winery_Hugh Hamilton]
# 16                           [country_Australia, winery_Innocent Bystander]
# 17                              [country_Australia, winery_Kangarilla Road]
# 18                                     [country_Australia, winery_Torbreck]
# 19                                      [country_Australia, winery_Yalumba]
# 20                               [country_Australia, winery_Yering Station]
# 21                                       [country_Australia, price_level_A]
# 22                                       [country_Australia, price_level_B]
# 23                                       [country_Australia, price_level_C]
# 24                                       [country_Australia, price_level_D]
# 25                     [winery_Domaine Terlato & Chapoutier, price_level_D]
# 26                               [winery_Innocent Bystander, price_level_D]
# 27                                  [winery_Kangarilla Road, price_level_D]
# 28                                         [winery_Torbreck, price_level_A]
# 29  [country_Australia, winery_Domaine Terlato & Chapoutier, price_level_D]
# 30            [country_Australia, winery_Innocent Bystander, price_level_D]
# 31               [country_Australia, winery_Kangarilla Road, price_level_D]
# 32                      [country_Australia, winery_Torbreck, price_level_A]

# %%
#导出关联规则，计算支持度和置信度，并使用lift、leverage、conviction指标对规则进行评价，设置lift 最小值为1.5
rules1 =  association_rules(frequent_itemsets1, metric='lift', min_threshold=1.5)
rules1
# Out:
#                                                  antecedants  \
# 0                                            (price_level_D)
# 1                      (winery_Domaine Terlato & Chapoutier)
# 2                                            (price_level_D)
# 3                                (winery_Innocent Bystander)
# 4                                            (price_level_D)
# 5                                   (winery_Kangarilla Road)
# 6                                            (price_level_A)
# 7                                          (winery_Torbreck)
# 8                         (price_level_D, country_Australia)
# 9   (winery_Domaine Terlato & Chapoutier, country_Australia)
# 10                                           (price_level_D)
# 11                     (winery_Domaine Terlato & Chapoutier)
# 12                        (price_level_D, country_Australia)
# 13            (country_Australia, winery_Innocent Bystander)
# 14                                           (price_level_D)
# 15                               (winery_Innocent Bystander)
# 16                        (price_level_D, country_Australia)
# 17               (country_Australia, winery_Kangarilla Road)
# 18                                           (price_level_D)
# 19                                  (winery_Kangarilla Road)
# 20                        (price_level_A, country_Australia)
# 21                      (country_Australia, winery_Torbreck)
# 22                                           (price_level_A)
# 23                                         (winery_Torbreck)
#
#                                                  consequents  \
# 0                      (winery_Domaine Terlato & Chapoutier)
# 1                                            (price_level_D)
# 2                                (winery_Innocent Bystander)
# 3                                            (price_level_D)
# 4                                   (winery_Kangarilla Road)
# 5                                            (price_level_D)
# 6                                          (winery_Torbreck)
# 7                                            (price_level_A)
# 8                      (winery_Domaine Terlato & Chapoutier)
# 9                                            (price_level_D)
# 10  (winery_Domaine Terlato & Chapoutier, country_Australia)
# 11                        (price_level_D, country_Australia)
# 12                               (winery_Innocent Bystander)
# 13                                           (price_level_D)
# 14            (country_Australia, winery_Innocent Bystander)
# 15                        (price_level_D, country_Australia)
# 16                                  (winery_Kangarilla Road)
# 17                                           (price_level_D)
# 18               (country_Australia, winery_Kangarilla Road)
# 19                        (price_level_D, country_Australia)
# 20                                         (winery_Torbreck)
# 21                                           (price_level_A)
# 22                      (country_Australia, winery_Torbreck)
# 23                        (price_level_A, country_Australia)
#
#     antecedent support  consequent support   support  confidence      lift  \
# 0             0.604651            0.069767  0.069767    0.115385  1.653846
# 1             0.069767            0.604651  0.069767    1.000000  1.653846
# 2             0.604651            0.054264  0.054264    0.089744  1.653846
# 3             0.054264            0.604651  0.054264    1.000000  1.653846
# 4             0.604651            0.054264  0.054264    0.089744  1.653846
# 5             0.054264            0.604651  0.054264    1.000000  1.653846
# 6             0.054264            0.100775  0.054264    1.000000  9.923077
# 7             0.100775            0.054264  0.054264    0.538462  9.923077
# 8             0.573643            0.069767  0.069767    0.121622  1.743243
# 9             0.069767            0.604651  0.069767    1.000000  1.653846
# 10            0.604651            0.069767  0.069767    0.115385  1.653846
# 11            0.069767            0.573643  0.069767    1.000000  1.743243
# 12            0.573643            0.054264  0.054264    0.094595  1.743243
# 13            0.054264            0.604651  0.054264    1.000000  1.653846
# 14            0.604651            0.054264  0.054264    0.089744  1.653846
# 15            0.054264            0.573643  0.054264    1.000000  1.743243
# 16            0.573643            0.054264  0.054264    0.094595  1.743243
# 17            0.054264            0.604651  0.054264    1.000000  1.653846
# 18            0.604651            0.054264  0.054264    0.089744  1.653846
# 19            0.054264            0.573643  0.054264    1.000000  1.743243
# 20            0.054264            0.100775  0.054264    1.000000  9.923077
# 21            0.100775            0.054264  0.054264    0.538462  9.923077
# 22            0.054264            0.100775  0.054264    1.000000  9.923077
# 23            0.100775            0.054264  0.054264    0.538462  9.923077
#
#     leverage  conviction
# 0   0.027582    1.051567
# 1   0.027582         inf
# 2   0.021453    1.038978
# 3   0.021453         inf
# 4   0.021453    1.038978
# 5   0.021453         inf
# 6   0.048795         inf
# 7   0.048795    2.049096
# 8   0.029746    1.059034
# 9   0.027582         inf
# 10  0.027582    1.051567
# 11  0.029746         inf
# 12  0.023136    1.044545
# 13  0.021453         inf
# 14  0.021453    1.038978
# 15  0.023136         inf
# 16  0.023136    1.044545
# 17  0.021453         inf
# 18  0.021453    1.038978
# 19  0.023136         inf
# 20  0.048795         inf
# 21  0.048795    2.049096
# 22  0.048795         inf
# 23  0.048795    2.049096

# %%
#对挖掘结果进行分析：将lift值大于9的降序输出
rules1[(rules1.lift>9)].sort_values(by=['lift'], ascending=False)
# Out:
#                              antecedants  \
# 6                        (price_level_A)
# 7                      (winery_Torbreck)
# 20    (price_level_A, country_Australia)
# 21  (country_Australia, winery_Torbreck)
# 22                       (price_level_A)
# 23                     (winery_Torbreck)
#
#                              consequents  antecedent support  \
# 6                      (winery_Torbreck)            0.054264
# 7                        (price_level_A)            0.100775
# 20                     (winery_Torbreck)            0.054264
# 21                       (price_level_A)            0.100775
# 22  (country_Australia, winery_Torbreck)            0.054264
# 23    (price_level_A, country_Australia)            0.100775
#
#     consequent support   support  confidence      lift  leverage  conviction
# 6             0.100775  0.054264    1.000000  9.923077  0.048795         inf
# 7             0.054264  0.054264    0.538462  9.923077  0.048795    2.049096
# 20            0.100775  0.054264    1.000000  9.923077  0.048795         inf
# 21            0.054264  0.054264    0.538462  9.923077  0.048795    2.049096
# 22            0.100775  0.054264    1.000000  9.923077  0.048795         inf
# 23            0.054264  0.054264    0.538462  9.923077  0.048795    2.049096

# %%
#可视化展示：绘制关联规则支持度和置信度的散点图
plt.xlabel('support')
plt.ylabel('confidence')
plt.scatter(rules1.support,rules1.confidence)
plt.show()
